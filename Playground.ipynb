# %% [markdown]
# # Playground
#
# This notebook is a [Gitpod](https://www.gitpod.io/) based playground provided to let you experiment with LibLET.

# %%
from liblet import Tree

Tree('An example', [Tree('of'), Tree('tree')])
# Out:
# (An example: of, tree)
